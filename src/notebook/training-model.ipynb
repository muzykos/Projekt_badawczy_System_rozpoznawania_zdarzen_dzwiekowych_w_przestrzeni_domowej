# %% [markdown]
# # Projekt badawczy system rozpoznawania zdarzen dzwiekowych w przestrzeni domowej

# %% [markdown]
# # Spis treści

# %%
import librosa as lbs
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt
